# %%
from IPython.core.display import HTML, display
from string import Template
import pandas as pd
import json, random

# %%
HTML("<script src='d3.js'></script>")
# Out:
# <script src='d3.js'></script>

# %%
df = pd.read_csv("bar-data.csv", sep = ",")

# %%
df.head()
# Out:
#    date  value
# 0  2010      0
# 1  2011    165
# 2  2012    269
# 3  2013    344
# 4  2014    376

# %%
df_dict = df.to_dict(orient="records")
df_dict[:5]
# Out:
# [{'date': 2010, 'value': 0},
#  {'date': 2011, 'value': 165},
#  {'date': 2012, 'value': 269},
#  {'date': 2013, 'value': 344},
#  {'date': 2014, 'value': 376}]

# %%
js_text_template = Template('''
var margin = {top: 20, right: 20, bottom: 70, left: 40},
    width = 720 - margin.left - margin.right,
    height = 300 - margin.top - margin.bottom;

var x = d3.scale.linear().range([0, width]);

var y = d3.scale.linear().range([height, 0]);

var xAxis = d3.svg.axis()
    .scale(x)
    .orient("bottom")

var yAxis = d3.svg.axis()
    .scale(y)
    .orient("left")
    .ticks(10);

var color = d3.scale.category10();

var xAxis = d3.svg.axis()
.scale(x)
.orient("bottom");



var yAxis = d3.svg.axis()
.scale(y)
.orient("left");

var svg = d3.select("#$maid").append("svg")
.attr("width", width + margin.left+margin.left)
.attr("height", height + margin.top+margin.bottom)
.append("g")
.attr("transform","translate("+margin.left+","+margin.top+")")

var data = $python_data;



console.log(data)
x.domain(d3.extent(data,function(d) { return d.date;}));
y.domain(d3.extent(data,function(d) { return d.value}));


svg.append("g")
.attr("class","x axis")
.attr("transform","translate(20,"+height+")")
.call(xAxis)
.append("text")
.attr("transform","rotate(-90)")
.attr("class","label")
.attr("x",width)

svg.append("g")
.attr("class","y axis")
.call(yAxis)
.append("text")
.attr("transform","rotate(-90)")
.attr("class","label")
.attr("y",6)
.attr("dy",".71em")
.style("text-anchor","end")

svg.selectAll(".dot")
      .data(data)
    .enter().append("rect")
      .style("fill", "#E6E6FA")
      .attr("x", function(d) { return x(d.date); })
      .attr("width", 40)
      .attr("y", function(d) { return y(d.value); })
      .attr("height", function(d) { return height - y(d.value); });
      

step = 17  
var colors = ["#F08080", "#FFB6C1","LightYellow", "#E6E6FA", "#E0FFFF", "#FFDAB9", "#F08080", "#FFB6C1","LightYellow", "#E6E6FA", "#E0FFFF", "#FFDAB9"]
for (let i = 0; i < data.length - 2; i++){
      d = data[i]
      d2 = data[i + 1]
      
      console.log('d' , d)
      svg
        .append("line")        
        .attr("x1", step)
        .attr("y1", height - d.value/2 - 2)
        .attr("x2", step + 67)
        .attr("y2", height - d2.value/2 - 2 )
        .style("stroke", "blue") 
        .style("stroke-width", "3px") 
        step = step + 67
}


''');

# %%
html_template = Template('''
    <style>
    .dot{
        stroke: #000;
    }
    .legend{
        color:blue;
    }
    
    .axis path,
    .axis line{
        fill: none;
        shape-rendering:crispEdges;
    
    }
    </style>
    <div id="scatter-id"></div>
    <script>$js_text</script>
''')
js_text = js_text_template.substitute({
    "python_data":json.dumps(df_dict),
    "maid":"scatter-id"
})

# %%
HTML(html_template.substitute({'js_text':js_text}))
# Out:
#     <style>
#     .dot{
#         stroke: #000;
#     }
#     .legend{
#         color:blue;
#     }
#
#     .axis path,
#     .axis line{
#         fill: none;
#         shape-rendering:crispEdges;
#
#     }
#     </style>
#     <div id="scatter-id"></div>
#     <script>
# var margin = {top: 20, right: 20, bottom: 70, left: 40},
#     width = 720 - margin.left - margin.right,
#     height = 300 - margin.top - margin.bottom;
#
# var x = d3.scale.linear().range([0, width]);
#
# var y = d3.scale.linear().range([height, 0]);
#
# var xAxis = d3.svg.axis()
#     .scale(x)
#     .orient("bottom")
#
# var yAxis = d3.svg.axis()
#     .scale(y)
#     .orient("left")
#     .ticks(10);
#
# var color = d3.scale.category10();
#
# var xAxis = d3.svg.axis()
# .scale(x)
# .orient("bottom");
#
#
#
# var yAxis = d3.svg.axis()
# .scale(y)
# .orient("left");
#
# var svg = d3.select("#scatter-id").append("svg")
# .attr("width", width + margin.left+margin.left)
# .attr("height", height + margin.top+margin.bottom)
# .append("g")
# .attr("transform","translate("+margin.left+","+margin.top+")")
#
# var data = [{"date": 2010, "value": 0}, {"date": 2011, "value": 165}, {"date": 2012, "value": 269}, {"date": 2013, "value": 344}, {"date": 2014, "value": 376}, {"date": 2015, "value": 410}, {"date": 2016, "value": 100}, {"date": 2017, "value": 165}, {"date": 2018, "value": 269}, {"date": 2019, "value": 344}, {"date": 2020, "value": 376}, {"date": 2020, "value": 376}];
#
#
#
# console.log(data)
# x.domain(d3.extent(data,function(d) { return d.date;}));
# y.domain(d3.extent(data,function(d) { return d.value}));
#
#
# svg.append("g")
# .attr("class","x axis")
# .attr("transform","translate(20,"+height+")")
# .call(xAxis)
# .append("text")
# .attr("transform","rotate(-90)")
# .attr("class","label")
# .attr("x",width)
#
# svg.append("g")
# .attr("class","y axis")
# .call(yAxis)
# .append("text")
# .attr("transform","rotate(-90)")
# .attr("class","label")
# .attr("y",6)
# .attr("dy",".71em")
# .style("text-anchor","end")
#
# svg.selectAll(".dot")
#       .data(data)
#     .enter().append("rect")
#       .style("fill", "#E6E6FA")
#       .attr("x", function(d) { return x(d.date); })
#       .attr("width", 40)
#       .attr("y", function(d) { return y(d.value); })
#       .attr("height", function(d) { return height - y(d.value); });
#
#
# step = 17
# var colors = ["#F08080", "#FFB6C1","LightYellow", "#E6E6FA", "#E0FFFF", "#FFDAB9", "#F08080", "#FFB6C1","LightYellow", "#E6E6FA", "#E0FFFF", "#FFDAB9"]
# for (let i = 0; i < data.length - 2; i++){
#       d = data[i]
#       d2 = data[i + 1]
#
#       console.log('d' , d)
#       svg
#         .append("line")
#         .attr("x1", step)
#         .attr("y1", height - d.value/2 - 2)
#         .attr("x2", step + 67)
#         .attr("y2", height - d2.value/2 - 2 )
#         .style("stroke", "blue")
#         .style("stroke-width", "3px")
#         step = step + 67
# }
#
#
# </script>
